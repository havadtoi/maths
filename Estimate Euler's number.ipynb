# %%
x = 1
y = 1
for i in range(2, 19):
    y += 1 / x
    x *= i
    print(y)
# Out:
# 2.0
# 2.5
# 2.6666666666666665
# 2.708333333333333
# 2.7166666666666663
# 2.7180555555555554
# 2.7182539682539684
# 2.71827876984127
# 2.7182815255731922
# 2.7182818011463845
# 2.718281826198493
# 2.7182818282861687
# 2.7182818284467594
# 2.71828182845823
# 2.718281828458995
# 2.718281828459043
# 2.7182818284590455
